# %% [markdown]
# # Data Analysis On Iris Dataset

# %% [markdown]
# ![iris-dataset.png](attachment:iris-dataset.png)

# %% [markdown]
# #### Importing Liabraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# #### Reading Dataset

# %%
data = pd.read_csv("iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# #### Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# #### Statistical Information

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #### Top records

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### Top 10 Records

# %%
data.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# #### Bottom Records

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# #### Bottom 10 Records

# %%
data.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %% [markdown]
# #### Cheching Null Values

# %%
data.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# #### Dropping unnecessary Columns

# %%
data.drop(['Id'],axis=1,inplace=True)
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Checking for Duplicates

# %%
data.duplicated().sum()
# Out:
# 3

# %% [markdown]
# #### Value Counts as per each columns

# %%
data['SepalLengthCm'].value_counts()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64

# %%
data['SepalWidthCm'].value_counts()
# Out:
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: SepalWidthCm, dtype: int64

# %%
data['PetalLengthCm'].value_counts()
# Out:
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# 5.5     3
# 6.1     3
# 5.8     3
# 3.3     2
# 5.4     2
# 6.7     2
# 5.3     2
# 5.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 1.9     2
# 3.5     2
# 5.2     2
# 3.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 6.6     1
# 6.3     1
# 1.0     1
# 6.9     1
# 3.6     1
# 6.4     1
# Name: PetalLengthCm, dtype: int64

# %%
data['PetalWidthCm'].value_counts()
# Out:
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: PetalWidthCm, dtype: int64

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# #### Unique Values

# %%
data['SepalLengthCm'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
data['SepalWidthCm'].unique()
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 2.9, 3.7, 4. , 4.4, 3.8, 3.3,
#        4.1, 4.2, 2.3, 2.8, 2.4, 2.7, 2. , 2.2, 2.5, 2.6])

# %%
data['PetalLengthCm'].unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
data['PetalWidthCm'].unique()
# Out:
# array([0.2, 0.4, 0.3, 0.1, 0.5, 0.6, 1.4, 1.5, 1.3, 1.6, 1. , 1.1, 1.8,
#        1.2, 1.7, 2.5, 1.9, 2.1, 2.2, 2. , 2.4, 2.3])

# %% [markdown]
# #### Total number of unique values

# %%
data.nunique()
# Out:
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %% [markdown]
# #### Checking for duplicates

# %%
data.duplicated().sum()
# Out:
# 3

# %% [markdown]
# #### Samples of dataset

# %%
data.sample()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 120            6.9           3.2            5.7           2.3  Iris-virginica

# %% [markdown]
# #### Correlation

# %%
data.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %% [markdown]
# #### Covariance

# %%
data.cov()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       0.685694     -0.039268       1.273682      0.516904
# SepalWidthCm       -0.039268      0.188004      -0.321713     -0.117981
# PetalLengthCm       1.273682     -0.321713       3.113179      1.296387
# PetalWidthCm        0.516904     -0.117981       1.296387      0.582414

# %%
data.groupby(['SepalLengthCm','Species'])['SepalLengthCm'].count()
# Out:
# SepalLengthCm  Species
# 4.3            Iris-setosa        1
# 4.4            Iris-setosa        3
# 4.5            Iris-setosa        1
# 4.6            Iris-setosa        4
# 4.7            Iris-setosa        2
# 4.8            Iris-setosa        5
# 4.9            Iris-setosa        4
#                Iris-versicolor    1
#                Iris-virginica     1
# 5.0            Iris-setosa        8
#                Iris-versicolor    2
# 5.1            Iris-setosa        8
#                Iris-versicolor    1
# 5.2            Iris-setosa        3
#                Iris-versicolor    1
# 5.3            Iris-setosa        1
# 5.4            Iris-setosa        5
#                Iris-versicolor    1
# 5.5            Iris-setosa        2
#                Iris-versicolor    5
# 5.6            Iris-versicolor    5
#                Iris-virginica     1
# 5.7            Iris-setosa        2
#                Iris-versicolor    5
#                Iris-virginica     1
# ...

# %% [markdown]
# #### Grouping columns

# %%
data.groupby(['PetalLengthCm','Species'])['PetalLengthCm'].count()
# Out:
# PetalLengthCm  Species
# 1.0            Iris-setosa         1
# 1.1            Iris-setosa         1
# 1.2            Iris-setosa         2
# 1.3            Iris-setosa         7
# 1.4            Iris-setosa        12
# 1.5            Iris-setosa        14
# 1.6            Iris-setosa         7
# 1.7            Iris-setosa         4
# 1.9            Iris-setosa         2
# 3.0            Iris-versicolor     1
# 3.3            Iris-versicolor     2
# 3.5            Iris-versicolor     2
# 3.6            Iris-versicolor     1
# 3.7            Iris-versicolor     1
# 3.8            Iris-versicolor     1
# 3.9            Iris-versicolor     3
# 4.0            Iris-versicolor     5
# 4.1            Iris-versicolor     3
# 4.2            Iris-versicolor     4
# 4.3            Iris-versicolor     2
# 4.4            Iris-versicolor     4
# 4.5            Iris-versicolor     7
#                Iris-virginica      1
# 4.6            Iris-versicolor     3
# 4.7            Iris-versicolor     5
# ...

# %% [markdown]
# #### Pivot Tables

# %%
d1 = data.copy()
d1= d1.pivot_table('SepalLengthCm', columns='Species', aggfunc='sum')
d1
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# SepalLengthCm        250.3            296.8           329.4

# %%
d2 = data.copy()
d2= d2.pivot_table('PetalLengthCm', columns='Species', aggfunc='sum')
d2
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# PetalLengthCm         73.2            213.0           277.6

# %%
d3 = data.copy()
d3= d3.pivot_table('SepalWidthCm', columns='Species', aggfunc='sum')
d3
# Out:
# Species       Iris-setosa  Iris-versicolor  Iris-virginica
# SepalWidthCm        170.9            138.5           148.7

# %%
d4 = data.copy()
d4= d4.pivot_table('PetalWidthCm', columns='Species', aggfunc='sum')
d4
# Out:
# Species       Iris-setosa  Iris-versicolor  Iris-virginica
# PetalWidthCm         12.2             66.3           101.3

# %%
d5=data.copy()
d5['SepalLegthCm'] = data['SepalLengthCm'] * data['SepalWidthCm']
d5=d5.groupby(['Species'])['SepalLengthCm'].sum()
d5=pd.DataFrame(d5)
d5
# Out:
#                  SepalLengthCm
# Species
# Iris-setosa              250.3
# Iris-versicolor          296.8
# Iris-virginica           329.4

# %%
d6=data.copy()
d6['PetalLengthCm'] = data['PetalLengthCm'] * data['PetalWidthCm']
d6=d6.groupby(['Species'])['PetalLengthCm'].sum()
d6=pd.DataFrame(d6)
d6
# Out:
#                  PetalLengthCm
# Species
# Iris-setosa              18.14
# Iris-versicolor         286.02
# Iris-virginica          564.81

# %%
d7=data.groupby('Species').SepalLengthCm.sum().sort_values(ascending=False)
d7
# Out:
# Species
# Iris-virginica     329.4
# Iris-versicolor    296.8
# Iris-setosa        250.3
# Name: SepalLengthCm, dtype: float64

# %%
d8=data.groupby('Species').SepalWidthCm.sum().sort_values(ascending=False)
d8
# Out:
# Species
# Iris-setosa        170.9
# Iris-virginica     148.7
# Iris-versicolor    138.5
# Name: SepalWidthCm, dtype: float64

# %%
d9=data.groupby('Species').PetalLengthCm.sum().sort_values(ascending=False)
d9
# Out:
# Species
# Iris-virginica     277.6
# Iris-versicolor    213.0
# Iris-setosa         73.2
# Name: PetalLengthCm, dtype: float64

# %%
d10=data.groupby('Species').PetalWidthCm.sum().sort_values(ascending=False)
d10
# Out:
# Species
# Iris-virginica     101.3
# Iris-versicolor     66.3
# Iris-setosa         12.2
# Name: PetalWidthCm, dtype: float64

# %% [markdown]
# #### Crosstab

# %%
pd.crosstab(data['SepalLengthCm'], data['Species'])
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# SepalLengthCm
# 4.3                      1                0               0
# 4.4                      3                0               0
# 4.5                      1                0               0
# 4.6                      4                0               0
# 4.7                      2                0               0
# 4.8                      5                0               0
# 4.9                      4                1               1
# 5.0                      8                2               0
# 5.1                      8                1               0
# 5.2                      3                1               0
# 5.3                      1                0               0
# 5.4                      5                1               0
# 5.5                      2                5               0
# 5.6                      0                5               1
# ...

# %%
pd.crosstab(data['PetalLengthCm'], data['Species'])
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# PetalLengthCm
# 1.0                      1                0               0
# 1.1                      1                0               0
# 1.2                      2                0               0
# 1.3                      7                0               0
# 1.4                     12                0               0
# 1.5                     14                0               0
# 1.6                      7                0               0
# 1.7                      4                0               0
# 1.9                      2                0               0
# 3.0                      0                1               0
# 3.3                      0                2               0
# 3.5                      0                2               0
# 3.6                      0                1               0
# 3.7                      0                1               0
# ...

# %% [markdown]
# #### Dataframe

# %%
dd1=data.copy()

dd1['SepalLengthCm']= data['SepalLengthCm'] + data['SepalWidthCm']
dd1= dd1.groupby (['SepalLengthCm'])['Species'].max()
dd1=pd.DataFrame(dd1)
dd1
# Out:
#                        Species
# SepalLengthCm
# 6.8                Iris-setosa
# 7.0            Iris-versicolor
# 7.3            Iris-versicolor
# 7.3            Iris-versicolor
# 7.4             Iris-virginica
# 7.6            Iris-versicolor
# 7.6                Iris-setosa
# 7.7                Iris-setosa
# 7.8            Iris-versicolor
# 7.9            Iris-versicolor
# 8.0            Iris-versicolor
# 8.1            Iris-versicolor
# 8.2             Iris-virginica
# 8.3            Iris-versicolor
# 8.4             Iris-virginica
# 8.4            Iris-versicolor
# 8.5             Iris-virginica
# 8.6             Iris-virginica
# 8.7             Iris-virginica
# 8.8             Iris-virginica
# 8.9            Iris-versicolor
# 8.9             Iris-virginica
# 9.0             Iris-virginica
# 9.1             Iris-virginica
# 9.1             Iris-virginica
# 9.2             Iris-virginica
# 9.3            Iris-versicolor
# 9.4            Iris-versicolor
# ...

# %%
dd2 = data.copy()
dd2= dd2.pivot_table('SepalLengthCm', columns='Species', aggfunc='sum')
dd2
# Out:
# Species        Iris-setosa  Iris-versicolor  Iris-virginica
# SepalLengthCm        250.3            296.8           329.4

# %%
df=data.groupby("Species").mean()
df
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         3.418          1.464         0.244
# Iris-versicolor          5.936         2.770          4.260         1.326
# Iris-virginica           6.588         2.974          5.552         2.026

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(16,5))
print(data['SepalLengthCm'].value_counts())
plt.figure(figsize=(10,4))
sns.countplot(x=data['Species'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64

# %%
df=data.groupby("Species").mean()
df
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         3.418          1.464         0.244
# Iris-versicolor          5.936         2.770          4.260         1.326
# Iris-virginica           6.588         2.974          5.552         2.026

# %% [markdown]
# #### Pie Chart

# %%
plt.title('Species', fontsize=20)
data['Species'].value_counts().plot.pie(autopct= '%1.1f%%', shadow=True)
plt.show()

# %% [markdown]
# #### Heatmap

# %%
n1_data=['Species','SepalLengthCm','PetalLengthCm','SepalWidthCm','PetalWidthCm']
plt.figure(figsize=(10,5))
sns.heatmap(data[n1_data].corr(),annot=True,fmt='.4f',cmap='coolwarm_r',center=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Lineplot

# %%
plt.figure(figsize= (10,4))
sns.lineplot('SepalWidthCm', 'PetalWidthCm', data=data, color='r', label='Width')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Histogram

# %%
data.hist(bins=50, figsize=(25,20), color='red')
plt.show()

# %%
data['SepalLengthCm'].hist()
plt.show()

# %%
data['PetalLengthCm'].hist()
plt.show()

# %%
data['SepalWidthCm'].hist()
plt.show()

# %%
data['PetalWidthCm'].hist()
plt.show()

# %% [markdown]
# #### Scatterplot

# %%
colors= ['Red', 'Orange', 'Blue']
species=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
for i in range(3):
    x = data[data['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'],c=colors[i], label=species[i])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()
plt.show()

# %%
for i in range(3):
    x = data[data['Species'] == species[i]]
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'],c=colors[i], label=species[i])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend()
plt.show()

# %%
for i in range(3):
    x = data[data['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'],x['PetalLengthCm'],c=colors[i], label=species[i])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.legend()

# %%
for i in range(3):
    x = data[data['Species'] == species[i]]
    plt.scatter(x['SepalWidthCm'],x['PetalWidthCm'],c=colors[i], label=species[i])
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.legend()

# %% [markdown]
# #### Relation Plot

# %%
plt.subplots(nrows=1, ncols=1, sharex=True, figsize=(4,7))
sns.regplot(y=data['SepalLengthCm'],x=data['PetalLengthCm'])
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='SepalLengthCm'>

# %% [markdown]
# #### Correlation matrix

# %%
data.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr = data.corr()
fig, ax = plt.subplots(figsize=(6,5))
sns.heatmap(corr, annot=True, ax=ax, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(data,hue='Species')
plt.show()

# %% [markdown]
# #### Distribution Plot

# %%
sns.distplot(data['SepalLengthCm'],bins=10,kde=True)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %% [markdown]
# #### Box Plot

# %%
def graph(y):
    sns.boxplot(x="Species", y=y, data=data)
  
plt.figure(figsize=(10,10))
      
# Adding the subplot at the specified
# grid position
plt.subplot(221)
graph('SepalLengthCm')
  
plt.subplot(222)
graph('SepalWidthCm')
  
plt.subplot(223)
graph('PetalLengthCm')
  
plt.subplot(224)
graph('PetalWidthCm')
  
plt.show()

# %% [markdown]
# #### Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data['Species'] = le.fit_transform(data['Species'])
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# #### Model Training

# %%
from sklearn.model_selection import train_test_split
#train - 70
#test- 30
X= data.drop(columns=['Species'])
Y= data['Species']
x_train, x_test, y_train, y_test = train_test_split(X , Y, test_size=0.30)

# %% [markdown]
# #### Logistic regrassion

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# #### Model Training

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Accurarcy

# %%
print("Accurarcy: ",model.score(x_test,y_test )* 100)
# Out:
# Accurarcy:  93.33333333333333

# %% [markdown]
# #### KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  93.33333333333333

# %% [markdown]
# #### Dicision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  91.11111111111111
